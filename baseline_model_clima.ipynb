# %% [markdown]
# This notebook trains a model on the regional health data to predict the 2023 cases. This model includes epidemiological and climate data.
#
# To generate the predictions for the state, the model is applied to the data of each regional health, and the 100 predictions generated by each of them are summed to generate the predictions of the state.

# %%
import numpy as np
import pandas as pd
import preprocess_data as prep
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from models import build_baseline, train_model_using_cross_val, sum_regions_predictions
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
 
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)

'''
This script is used to train the model for a specific STATE and forecast the cases on a 
specific year (TEST_YEAR). The model is trained  with the regional health data before the year selected. 
'''
STATE = 'MG'
TEST_YEAR = 2023

# %%
df = prep.load_cases_data()
df = df.loc[df.uf == STATE]
df.head()
# Out:
#             year  epiweek  casos  geocode      regional  regional_geocode  \
# date
# 2010-01-03  2010   201001      0  3110806    Itambacuri             31096
# 2010-01-03  2010   201001      0  3132404       Itajubá             31003
# 2010-01-03  2010   201001      0  3168903   São Gotardo             31082
# 2010-01-03  2010   201001      0  3155405  Juiz de Fora             31097
# 2010-01-03  2010   201001      0  3170602        Piumhi             31093
#
#            macroregional  macroregional_geocode  uf  train_1  train_2  \
# date
# 2010-01-03      Nordeste                   3111  MG     True     True
# 2010-01-03           Sul                   3101  MG     True     True
# 2010-01-03      Noroeste                   3109  MG     True     True
# 2010-01-03       Sudeste                   3107  MG     True     True
# 2010-01-03           Sul                   3101  MG     True     True
#
#             target_1  target_2
# date
# 2010-01-03     False     False
# 2010-01-03     False     False
# 2010-01-03     False     False
# 2010-01-03     False     False
# 2010-01-03     False     False

# %%
code_to_state = {33: 'RJ', 32: 'ES', 41: 'PR', 23: 'CE', 21: 'MA',
 31: 'MG', 42: 'SC', 26: 'PE', 25: 'PB', 24: 'RN', 22: 'PI', 27: 'AL',
 28: 'SE', 35: 'SP', 43: 'RS', 15: 'PA', 16: 'AP', 14: 'RR',  11: 'RO',
 13: 'AM', 12: 'AC', 51: 'MT', 50: 'MS', 52: 'GO', 17: 'TO', 53: 'DF',
 29: 'BA'}

# %%
state_to_code = {state: code for code, state in code_to_state.items()}

state_to_code
# Out:
# {'RJ': 33,
#  'ES': 32,
#  'PR': 41,
#  'CE': 23,
#  'MA': 21,
#  'MG': 31,
#  'SC': 42,
#  'PE': 26,
#  'PB': 25,
#  'RN': 24,
#  'PI': 22,
#  'AL': 27,
#  'SE': 28,
#  'SP': 35,
#  'RS': 43,
#  'PA': 15,
#  'AP': 16,
#  'RR': 14,
#  'RO': 11,
#  'AM': 13,
#  'AC': 12,
#  'MT': 51,
#  'MS': 50,
#  'GO': 52,
#  'TO': 17,
#  'DF': 53,
#  'BA': 29}

# %%
df_clima = prep.load_climate_data()

df_clima = df_clima.loc[df_clima.geocode.astype(str).str[:2] == '31']
df_clima.head()
# Out:
#            date  epiweek  geocode  temp_min  temp_med  temp_max  precip_tot  \
# 2244 2009-12-27   200952  3100104   20.7208   23.4406   27.3525      5.5421
# 2245 2009-12-27   200952  3100203   21.2028   24.3718   28.6233      0.8166
# 2246 2009-12-27   200952  3100302   20.0611   23.8270   28.7545      0.9051
# 2247 2009-12-27   200952  3100401   18.9060   22.3913   27.7191      2.7522
# 2248 2009-12-27   200952  3100500   20.1577   24.5404   29.9290      0.5607
#
#       rel_humid_med  temp_amp
# 2244        84.8923    6.6317
# 2245        79.5011    7.4205
# 2246        78.3925    8.6934
# 2247        79.8940    8.8131
# 2248        75.4242    9.7713

# %%
df_end = df.merge(df_clima, left_on = ['date', 'epiweek', 'geocode'], right_on = ['date', 'epiweek', 'geocode'])

df_end.date = pd.to_datetime(df_end.date)

df_end.set_index('date', inplace = True)

df_end.head()
# Out:
#             year  epiweek  casos  geocode      regional  regional_geocode  \
# date
# 2010-01-03  2010   201001      0  3110806    Itambacuri             31096
# 2010-01-03  2010   201001      0  3132404       Itajubá             31003
# 2010-01-03  2010   201001      0  3168903   São Gotardo             31082
# 2010-01-03  2010   201001      0  3155405  Juiz de Fora             31097
# 2010-01-03  2010   201001      0  3170602        Piumhi             31093
#
#            macroregional  macroregional_geocode  uf  train_1  train_2  \
# date
# 2010-01-03      Nordeste                   3111  MG     True     True
# 2010-01-03           Sul                   3101  MG     True     True
# 2010-01-03      Noroeste                   3109  MG     True     True
# 2010-01-03       Sudeste                   3107  MG     True     True
# 2010-01-03           Sul                   3101  MG     True     True
#
#             target_1  target_2  temp_min  temp_med  temp_max  precip_tot  \
# date
# 2010-01-03     False     False   21.9829   26.5957   32.0409      0.1879
# 2010-01-03     False     False   18.5711   22.3066   27.3997      3.1666
# 2010-01-03     False     False   19.2286   23.4808   28.1682      1.6369
# 2010-01-03     False     False   22.1361   26.4140   31.8807      0.9042
# 2010-01-03     False     False   19.4717   23.8841   28.7656      0.7958
#
#             rel_humid_med  temp_amp
# date
# 2010-01-03        69.7659   10.0580
# 2010-01-03        78.2605    8.8286
# 2010-01-03        75.2743    8.9396
# 2010-01-03        75.2398    9.7446
# 2010-01-03        73.9370    9.2939

# %%
enso = prep.load_sea_indicators()

enso.head()
# Out:
#                 enso       iod       pdo epiweek_label  epiweek  year
# date
# 2010-01-10  1.230226 -0.419708 -0.115554        201014       14  2010
# 2010-01-17  1.070318 -0.443917  0.061606        201015       15  2010
# 2010-01-24  0.957734 -0.154522  0.207900        201016       16  2010
# 2010-01-31  1.210819 -0.069680  0.385610        201017       17  2010
# 2010-02-07  1.210819 -0.069680  0.385610        201018       18  2010

# %%
# generate the samples to train and test based on the regional data 
columns_to_normalize = ['casos', 'epiweek', 'temp_med', 'temp_amp', 'rel_humid_med', 'precip_tot', 'enso', 'iod', 'pdo',
                            'R0', 'total_cases',
                             'peak_week', 'perc_geocode']

X_train, y_train = prep.generate_regional_train_samples(df_end, enso, TEST_YEAR, columns_to_normalize, True, True)

# %%
X_train.shape
# Out:
# (890, 89, 14)

# %%
batch_size = 4
LOSS = 'msle'
model_name = 'notebook'
activation = 'relu'

# %%
model = build_baseline(hidden=64, loss = LOSS, 
                      features=14, predict_n=52, look_back=89, batch_size = batch_size, optimizer = Adam(learning_rate = 0.001),
                     activation = activation)
model
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/train_lstm/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (4, 89, 14)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (4, 89, 64)            │        20,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (4, 89, 64)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (4, 64)                │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (4, 64)                │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (4, 52)                │         3,380 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 56,628 (221.20 KB)
#  Trainable params: 56,628 (221.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# <Functional name=functional, built=True>

# %%
# %%time 
model = train_model_using_cross_val(model, X_train, y_train, n_splits=4, epochs = 5,
                                verbose = 1,
                                batch_size = batch_size, 
                                monitor = 'val_loss',
                                min_delta = 0,
                                patience = 10)
# Out:
# Training fold 1...
# Epoch 1/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.0397 - loss: 0.0086 - mape: 4141153.5000 - mse: 0.0142 - val_accuracy: 0.0628 - val_loss: 0.0074 - val_mape: 3084257.7500 - val_mse: 0.0125
# Epoch 2/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.0723 - loss: 0.0069 - mape: 3269880.2500 - mse: 0.0116 - val_accuracy: 0.1345 - val_loss: 0.0069 - val_mape: 1941905.6250 - val_mse: 0.0121
# Epoch 3/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.1005 - loss: 0.0073 - mape: 2477815.0000 - mse: 0.0128 - val_accuracy: 0.1031 - val_loss: 0.0065 - val_mape: 2210563.5000 - val_mse: 0.0115
# Epoch 4/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.0947 - loss: 0.0056 - mape: 2425006.0000 - mse: 0.0096 - val_accuracy: 0.1345 - val_loss: 0.0059 - val_mape: 1870763.8750 - val_mse: 0.0104
# Epoch 5/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.1150 - loss: 0.0060 - mape: 1916518.3750 - mse: 0.0105 - val_accuracy: 0.1435 - val_loss: 0.0064 - val_mape: 783354.3125 - val_mse: 0.0112
# Training fold 2...
# Epoch 1/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.1132 - loss: 0.0057 - mape: 1552086.0000 - mse: 0.0098 - val_accuracy: 0.1211 - val_loss: 0.0069 - val_mape: 1573442.2500 - val_mse: 0.0120
# Epoch 2/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.1172 - loss: 0.0058 - mape: 1680528.1250 - mse: 0.0100 - val_accuracy: 0.1166 - val_loss: 0.0061 - val_mape: 1622635.8750 - val_mse: 0.0106
# Epoch 3/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.1214 - loss: 0.0055 - mape: 1463114.6250 - mse: 0.0096 - val_accuracy: 0.1525 - val_loss: 0.0064 - val_mape: 1881493.7500 - val_mse: 0.0111
# Epoch 4/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.1194 - loss: 0.0051 - mape: 1415905.1250 - mse: 0.0088 - val_accuracy: 0.1211 - val_loss: 0.0057 - val_mape: 1592638.2500 - val_mse: 0.0102
# Epoch 5/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.1097 - loss: 0.0053 - mape: 1657506.3750 - mse: 0.0094 - val_accuracy: 0.1928 - val_loss: 0.0057 - val_mape: 1088268.1250 - val_mse: 0.0100
# Training fold 3...
# Epoch 1/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.1186 - loss: 0.0053 - mape: 1627357.1250 - mse: 0.0094 - val_accuracy: 0.1712 - val_loss: 0.0048 - val_mape: 1427923.1250 - val_mse: 0.0087
# Epoch 2/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.1083 - loss: 0.0059 - mape: 1498093.7500 - mse: 0.0106 - val_accuracy: 0.1667 - val_loss: 0.0047 - val_mape: 1057749.5000 - val_mse: 0.0085
# Epoch 3/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.1466 - loss: 0.0050 - mape: 1773102.6250 - mse: 0.0088 - val_accuracy: 0.1667 - val_loss: 0.0046 - val_mape: 1385412.5000 - val_mse: 0.0085
# Epoch 4/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.1142 - loss: 0.0053 - mape: 1626270.1250 - mse: 0.0095 - val_accuracy: 0.1441 - val_loss: 0.0049 - val_mape: 1776899.7500 - val_mse: 0.0087
# Epoch 5/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.1133 - loss: 0.0052 - mape: 1769051.3750 - mse: 0.0092 - val_accuracy: 0.2072 - val_loss: 0.0047 - val_mape: 1476324.8750 - val_mse: 0.0086
# Training fold 4...
# Epoch 1/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.1123 - loss: 0.0049 - mape: 1452377.7500 - mse: 0.0087 - val_accuracy: 0.1532 - val_loss: 0.0047 - val_mape: 2063394.6250 - val_mse: 0.0083
# Epoch 2/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.1324 - loss: 0.0056 - mape: 1943402.1250 - mse: 0.0098 - val_accuracy: 0.1486 - val_loss: 0.0045 - val_mape: 1591864.6250 - val_mse: 0.0082
# Epoch 3/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.1469 - loss: 0.0047 - mape: 1527061.8750 - mse: 0.0084 - val_accuracy: 0.1216 - val_loss: 0.0051 - val_mape: 2727476.7500 - val_mse: 0.0086
# Epoch 4/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.1004 - loss: 0.0049 - mape: 1930659.0000 - mse: 0.0086 - val_accuracy: 0.1261 - val_loss: 0.0045 - val_mape: 2213230.5000 - val_mse: 0.0079
# Epoch 5/5
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.1538 - loss: 0.0051 - mape: 1828469.3750 - mse: 0.0092 - val_accuracy: 0.1757 - val_loss: 0.0044 - val_mape: 1261325.5000 - val_mse: 0.0079
# CPU times: user 1min 20s, sys: 4.25 s, total: 1min 24s
# Wall time: 1min 22s

# %%
model.save(f'./saved_models/model_climate_{STATE}_{TEST_YEAR-1}_{model_name}.keras')

# %%
# %%time
df_preds = sum_regions_predictions(model, df_end, enso, TEST_YEAR, columns_to_normalize)

df_preds.head()
# Out:
# CPU times: user 21min 46s, sys: 4.38 s, total: 21min 50s
# Wall time: 22min 16s
#        dates  lower  preds  upper
# 0 2022-10-09    0.0    0.0    0.0
# 1 2022-10-16    0.0    0.0    0.0
# 2 2022-10-23    0.0    0.0    0.0
# 3 2022-10-30    0.0    0.0    0.0
# 4 2022-11-06    0.0    0.0    0.0

# %%
df_preds.to_csv(f'./predictions/preds_climate_{STATE}_{TEST_YEAR}_{model_name}.csv', index = False)

# %%
df = prep.load_cases_data()
df = df.loc[df.uf == STATE]
df = df[['casos']].resample('W-SUN').sum()
df.head()
# Out:
#             casos
# date
# 2010-01-03   2794
# 2010-01-10   3729
# 2010-01-17   4656
# 2010-01-24   6195
# 2010-01-31   7179

# %%
fig, ax = plt.subplots()

ax.plot(df.loc[df.index.isin(df_preds.dates)].casos, label = 'Data')

ax.plot(df_preds.dates, df_preds.preds, label = 'preds', color = 'tab:orange')

ax.fill_between( df_preds.dates, df_preds.lower, df_preds.upper, color = 'tab:orange', alpha = 0.2)

ax.set_title(f'MG ')

plt.show()
