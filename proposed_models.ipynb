# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from models import build_baseline, build_lstm_att, build_lstm_att_2, build_lstm_att_3, build_att_lstm
from tensorflow.keras.utils import plot_model

# %%
LOSS = 'mse'
batch_size = 4
activation = 'relu'

# %% [markdown]
# ### Baseline model:

# %%
model = build_baseline(hidden=32, features=3, predict_n=52, look_back=89, loss=LOSS, 
                    stateful = False, batch_size = batch_size,  optimizer = 'adam', activation = 'relu')

plot_model(model, show_shapes = False, dpi = 75)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/lstm_infodengue_sprint/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (4, 89, 3)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (4, 89, 32)            │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (4, 89, 32)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (4, 32)                │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (4, 32)                │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (4, 52)                │         1,716 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,644 (57.20 KB)
#  Trainable params: 14,644 (57.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model = build_att_lstm(hidden=32, features=3, predict_n=52, look_back=89, loss=LOSS, 
                    stateful = False, batch_size = batch_size,  optimizer = 'adam', activation = 'relu')

plot_model(model, show_shapes = True, dpi = 75)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/lstm_infodengue_sprint/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (4, 89, 3)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (4, 32)           │      4,608 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (4, 32)           │          0 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Multi-Head          │ (4, 32)           │      1,211 │ dropout[0][0],    │
# │ (MultiHeadAttentio… │                   │            │ dropout[0][0],    │
# │                     │                   │            │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (4, 32)           │          0 │ Multi-Head[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (4, 52)           │      1,716 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,535 (29.43 KB)
#  Trainable params: 7,535 (29.43 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ### Simple model using attention:

# %%
model = build_lstm_att(hidden=32, features=3, predict_n=52, look_back=89, loss=LOSS, 
                    stateful = False, batch_size = batch_size,  optimizer = 'adam', activation = 'relu')

plot_model(model, show_shapes = True, dpi = 35)

# %%
model = build_lstm_att_2(hidden=32, features=3, predict_n=52, look_back=89, loss=LOSS, 
                    stateful = False, batch_size = batch_size,  optimizer = 'adam', activation = 'relu')

plot_model(model, show_shapes = True, dpi = 35)

# %%
model = build_lstm_att_3(hidden=32, features=3, predict_n=52, look_back=89, loss=LOSS, 
                    stateful = False, batch_size = batch_size,  optimizer = 'adam', activation = 'relu')

plot_model(model, show_shapes = True, dpi = 35)

# %% [markdown]
# ### Model combining the two models above:

# %%
model = build_comb_lstm_att(hidden=32, features=3, predict_n=52, look_back=89, loss=LOSS, 
                    stateful = False, batch_size = batch_size,  optimizer = 'adam', activation = 'relu')

plot_model(model, show_shapes = False, dpi = 75)
